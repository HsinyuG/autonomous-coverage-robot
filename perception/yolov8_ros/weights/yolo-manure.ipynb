# %% [markdown]
# ## Install yolov8

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()

# %% [markdown]
# ## Train

# %% [markdown]
# First specify the logger to use (Comet is default, you need to enter your API key)

# %%
#@title Select YOLOv8 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir .

# %% [markdown]
# Train model, now for 30 epochs

# %%
# !yolo train model=yolov8n.pt data=/kaggle/input/mirte-cow-manure/data.yaml epochs=30 imgsz=640

# %% [markdown]
# ## Inference
# Perform inference on random test image

# %%
from PIL import Image

model_path = '/kaggle/working/SOMETHING/runs/detect/train/weights/best.pt'
model = ultralytics.YOLO(model_path)

test_img = "/kaggle/input/mirte-cow-manure/test/images/captured_image_1716401253-386715_jpg.rf.5336ba883cafc5b85dbeebc3b4139558.jpg"

img = Image.open(test_img)

results = model(img)

results[0].show()
